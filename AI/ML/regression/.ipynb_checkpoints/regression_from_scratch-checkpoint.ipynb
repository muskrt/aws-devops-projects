# %%
import os
import sys
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('test.csv')
rna=np.random.rand(100,2)*100
rna=np.random.uniform(low=0.5, high=1, size=(100,2))*100
print(rna[:10][1])
# Out:
# [92.76788952 51.89569443]

# %%
df=pd.DataFrame(rna,columns=['x','y'])
print(df)
xpoints=df['x']
ypoints=df['y']
print(ypoints)
# Out:
#             x          y
# 0   95.006001  68.368561
# 1   94.747912  89.831370
# 2   84.074444  79.890066
# 3   83.780062  79.884379
# 4   63.909934  61.128721
# ..        ...        ...
# 95  59.975588  83.169709
# 96  91.968778  92.281961
# 97  92.944715  75.148795
# 98  68.948799  89.626673
# 99  83.306303  77.900413
#
# [100 rows x 2 columns]
# 0     68.368561
# 1     89.831370
# 2     79.890066
# 3     79.884379
# 4     61.128721
#         ...
# 95    83.169709
# 96    92.281961
# 97    75.148795
# 98    89.626673
# 99    77.900413
# Name: y, Length: 100, dtype: float64

# %%
plt.scatter(xpoints,ypoints)
plt.show()

# %%
tst()
# Out:
# func tst
